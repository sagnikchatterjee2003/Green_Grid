# %%
import mysql.connector
import csv
import logging

# %%
# Set up logging for debugging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Function to create and populate the zones table
def create_zones_table(csv_file_path):
    conn = None
    cursor = None
    try:
        conn = mysql.connector.connect(
            host="localhost",
            user="root",
            password="root",
            port = 3306,
            database="green-grid"
        )
        cursor = conn.cursor()

        cursor.execute('''
            CREATE TABLE IF NOT EXISTS zones (
                zone_id INT PRIMARY KEY,
                zone_name VARCHAR(50)
            )
        ''')

        with open(csv_file_path, 'r', encoding='utf-8-sig') as csv_file:
            csv_reader = csv.reader(csv_file)
            next(csv_reader)  # Skip header row
            for row in csv_reader:
                logging.info(f"Inserting row into zones: {row}")
                cursor.execute('''
                    INSERT IGNORE INTO zones (zone_id, zone_name)
                    VALUES (%s, %s)
                ''', row)

        conn.commit()
        print("Zones table created and data inserted successfully.")

    except mysql.connector.Error as err:
        print(f"MySQL Error: {err}")
        logging.error(f"MySQL Error in zones table: {err}")
    except FileNotFoundError as err:
        print(f"File Error: {err}")
        logging.error(f"File Error for zones CSV: {err}")
    except Exception as err:
        print(f"Unexpected Error: {err}")
        logging.error(f"Unexpected Error in zones table: {err}")
    finally:
        if cursor:
            cursor.close()
        if conn:
            conn.close()

# Function to create and populate the customers table
def create_customers_table(csv_file_path):
    conn = None
    cursor = None
    try:
        conn = mysql.connector.connect(
            host="localhost",
            user="root",
            password="root",
            port = 3306,
            database="green-grid"
        )
        cursor = conn.cursor()

        cursor.execute('''
            CREATE TABLE IF NOT EXISTS customers (
                customer_id INT PRIMARY KEY,
                customer_name VARCHAR(100),
                email VARCHAR(100),
                phone VARCHAR(20),
                zone_id INT,
                FOREIGN KEY (zone_id) REFERENCES zones(zone_id)
            )
        ''')

        with open(csv_file_path, 'r', encoding='utf-8-sig') as csv_file:
            csv_reader = csv.reader(csv_file)
            next(csv_reader)  # Skip header row
            for row in csv_reader:
                logging.info(f"Inserting row into customers: {row}")
                cursor.execute('''
                    INSERT IGNORE INTO customers (customer_id, customer_name, email, phone, zone_id)
                    VALUES (%s, %s, %s, %s, %s)
                ''', row)

        conn.commit()
        print("Customers table created and data inserted successfully.")

    except mysql.connector.Error as err:
        print(f"MySQL Error: {err}")
        logging.error(f"MySQL Error in customers table: {err}")
    except FileNotFoundError as err:
        print(f"File Error: {err}")
        logging.error(f"File Error for customers CSV: {err}")
    except Exception as err:
        print(f"Unexpected Error: {err}")
        logging.error(f"Unexpected Error in customers table: {err}")
    finally:
        if cursor:
            cursor.close()
        if conn:
            conn.close()

# Function to create and populate the meters table
def create_meters_table(csv_file_path):
    conn = None
    cursor = None
    try:
        conn = mysql.connector.connect(
            host="localhost",
            user="root",
            password="root",
            port = 3306,
            database="green-grid"
        )
        cursor = conn.cursor()

        cursor.execute('''
            CREATE TABLE IF NOT EXISTS meters (
                meter_id INT PRIMARY KEY,
                customer_id INT,
                installation_date DATE,
                FOREIGN KEY (customer_id) REFERENCES customers(customer_id)
            )
        ''')

        with open(csv_file_path, 'r', encoding='utf-8-sig') as csv_file:
            csv_reader = csv.reader(csv_file)
            next(csv_reader)  # Skip header row
            for row in csv_reader:
                logging.info(f"Inserting row into meters: {row}")
                cursor.execute('''
                    INSERT IGNORE INTO meters (meter_id, customer_id, installation_date)
                    VALUES (%s, %s, %s)
                ''', row)

        conn.commit()
        print("Meters table created and data inserted successfully.")

    except mysql.connector.Error as err:
        print(f"MySQL Error: {err}")
        logging.error(f"MySQL Error in meters table: {err}")
    except FileNotFoundError as err:
        print(f"File Error: {err}")
        logging.error(f"File Error for meters CSV: {err}")
    except Exception as err:
        print(f"Unexpected Error: {err}")
        logging.error(f"Unexpected Error in meters table: {err}")
    finally:
        if cursor:
            cursor.close()
        if conn:
            conn.close()

# Function to create and populate the billing table
def create_billing_table(csv_file_path):
    conn = None
    cursor = None
    try:
        conn = mysql.connector.connect(
            host="localhost",
            user="root",
            password="root",
            port = 3306,
            database="green-grid"
        )
        cursor = conn.cursor()

        cursor.execute('''
            CREATE TABLE IF NOT EXISTS billing (
                bill_id VARCHAR(36) PRIMARY KEY,
                meter_id INT,
                billing_date DATE,
                amount DECIMAL(10,2),
                payment_status VARCHAR(50),
                FOREIGN KEY (meter_id) REFERENCES meters(meter_id)
            )
        ''')

        with open(csv_file_path, 'r', encoding='utf-8-sig') as csv_file:
            csv_reader = csv.reader(csv_file)
            next(csv_reader)  # Skip header row
            for row in csv_reader:
                logging.info(f"Inserting row into billing: {row}")
                cursor.execute('''
                    INSERT IGNORE INTO billing (bill_id, meter_id, billing_date, amount, payment_status)
                    VALUES (%s, %s, %s, %s, %s)
                ''', row)

        conn.commit()
        print("Billing table created and data inserted successfully.")

    except mysql.connector.Error as err:
        print(f"MySQL Error: {err}")
        logging.error(f"MySQL Error in billing table: {err}")
    except FileNotFoundError as err:
        print(f"File Error: {err}")
        logging.error(f"File Error for billing CSV: {err}")
    except Exception as err:
        print(f"Unexpected Error: {err}")
        logging.error(f"Unexpected Error in billing table: {err}")
    finally:
        if cursor:
            cursor.close()
        if conn:
            conn.close()

# Function to create and populate the consumption_logs table
def create_consumption_logs_table(csv_file_path):
    conn = None
    cursor = None
    try:
        conn = mysql.connector.connect(
            host="localhost",
            user="root",
            password="root",
            port = 3306,
            database="green-grid"
        )
        cursor = conn.cursor()

        cursor.execute('''
            CREATE TABLE IF NOT EXISTS consumption_logs (
                log_id VARCHAR(50) PRIMARY KEY,
                meter_id INT,
                reading_date DATE,
                reading_time TIME,
                units_consumed DECIMAL(10,2),
                FOREIGN KEY (meter_id) REFERENCES meters(meter_id)
            )
        ''')

        with open(csv_file_path, 'r', encoding='utf-8-sig') as csv_file:
            csv_reader = csv.reader(csv_file)
            next(csv_reader)  # Skip header row
            for row in csv_reader:
                logging.info(f"Inserting row into consumption_logs: {row}")
                cursor.execute('''
                    INSERT IGNORE INTO consumption_logs (log_id, meter_id, reading_date, reading_time, units_consumed)
                    VALUES (%s, %s, %s, %s, %s)
                ''', row)

        conn.commit()
        print("Consumption logs table created and data inserted successfully.")

    except mysql.connector.Error as err:
        print(f"MySQL Error: {err}")
        logging.error(f"MySQL Error in consumption_logs table: {err}")
    except FileNotFoundError as err:
        print(f"File Error: {err}")
        logging.error(f"File Error for consumption_logs CSV: {err}")
    except Exception as err:
        print(f"Unexpected Error: {err}")
        logging.error(f"Unexpected Error in consumption_logs table: {err}")
    finally:
        if cursor:
            cursor.close()
        if conn:
            conn.close()

# %%
if __name__ == "__main__":
    create_zones_table('../zone.csv')
    create_customers_table('customer.csv')
    create_meters_table('meter.csv')
    create_billing_table('billing.csv')
    create_consumption_logs_table('consumption_log.csv')
# Out:
# 2025-06-16 20:26:09,552 - INFO - Inserting row into zones: ['1', 'Zone_1']
# 2025-06-16 20:26:09,553 - INFO - Inserting row into zones: ['2', 'Zone_2']
# 2025-06-16 20:26:09,554 - INFO - Inserting row into zones: ['3', 'Zone_3']
# 2025-06-16 20:26:09,554 - INFO - Inserting row into zones: ['4', 'Zone_4']
# 2025-06-16 20:26:09,555 - INFO - Inserting row into zones: ['5', 'Zone_5']
# Zones table created and data inserted successfully.
# 2025-06-16 20:26:11,642 - INFO - Inserting row into customers: ['1', 'Michelle Morales', 'christian29@yahoo.com', '+1-894-627-7682', '5']
# 2025-06-16 20:26:11,644 - INFO - Inserting row into customers: ['2', 'Tanya Randall', 'hwilliams@yahoo.com', '+1-613-144-0432x597', '3']
# 2025-06-16 20:26:11,644 - INFO - Inserting row into customers: ['3', 'Alicia Saunders', 'lisareyes@hotmail.com', '(041)538-7857', '5']
# 2025-06-16 20:26:11,645 - INFO - Inserting row into customers: ['4', 'Heather Brown', 'jcunningham@yahoo.com', '812-146-6377', '3']
# 2025-06-16 20:26:11,645 - INFO - Inserting row into customers: ['5', 'Richard Sanchez', 'johnsmith@hotmail.com', '(245)016-8955x734', '5']
# 2025-06-16 20:26:11,645 - INFO - Inserting row into customers: ['6', 'Whitney Kim', 'lorithompson@oconnor.com', '968-898-4431', '2']
# 2025-06-16 20:26:11,646 - INFO - Inserting row into customers: ['7', 'Helen Ramirez', 'dorothyhill@thompson-oliver.biz', '001-016-805-2477x123', '3']
# 2025-06-16 20:26:11,646 - INFO - Inserting row into customers: ['8', 'Marc Gonzalez', 'wsosa@banks.com', '001-198-425-8034x54735', '2']
# 2025-06-16 20:26:11,647 - INFO - Inserting row into customers: ['9', 'Nicholas Cruz', 'ronald71@miller.org', '+1-868-718-0043x45682', '5']
# 2025-06-16 20:26:11,647 - INFO - Inserting row into customers: ['10', 'John Brown', 'cookjill@gmail.com', '018-520-4242x958', '2']
# 2025-06-16 20:26:11,648 - INFO - Inserting row into customers: ['11', 'Rachel Barry', 'taylorcheryl@yahoo.com', '224-105-4772', '1']
# 2025-06-16 20:26:11,648 - INFO - Inserting row into customers: ['12', 'Meghan Valentine', 'denise13@banks-smith.com', '604-649-8864', '1']
# 2025-06-16 20:26:11,648 - INFO - Inserting row into customers: ['13', 'Darlene Chan', 'leonardcolleen@thomas-lopez.com', '+1-349-862-5088x6917', '5']
# 2025-06-16 20:26:11,650 - INFO - Inserting row into customers: ['14', 'Ian Bernard', 'erikkent@sawyer.com', '(006)916-9557x164', '2']
# 2025-06-16 20:26:11,650 - INFO - Inserting row into customers: ['15', 'Evelyn Baker', 'pthompson@hotmail.com', '(649)613-6541', '2']
# 2025-06-16 20:26:11,651 - INFO - Inserting row into customers: ['16', 'Sarah Mcguire', 'brownbrandon@gmail.com', '(198)251-2939x23033', '5']
# 2025-06-16 20:26:11,651 - INFO - Inserting row into customers: ['17', 'Sandra Johnson', 'jeremy29@yahoo.com', '179-380-1359x5532', '3']
# 2025-06-16 20:26:11,652 - INFO - Inserting row into customers: ['18', 'Christopher Allen', 'ihiggins@gmail.com', '(204)626-7171x75676', '5']
# 2025-06-16 20:26:11,652 - INFO - Inserting row into customers: ['19', 'John Pierce', 'amber32@hotmail.com', '877.247.2726', '3']
# 2025-06-16 20:26:11,652 - INFO - Inserting row into customers: ['20', 'Ruben Oconnor', 'aprilreilly@hotmail.com', '(576)100-5565x33889', '1']
# 2025-06-16 20:26:11,653 - INFO - Inserting row into customers: ['21', 'Margaret Horton', 'thouse@hotmail.com', '001-370-383-4201x3880', '2']
# 2025-06-16 20:26:11,653 - INFO - Inserting row into customers: ['22', 'Michael Blanchard', 'umccormick@hotmail.com', '+1-741-713-0138x00367', '2']
# 2025-06-16 20:26:11,653 - INFO - Inserting row into customers: ['23', 'Sandra Peterson', 'joe46@brown.biz', '644-102-8168x926', '4']
# 2025-06-16 20:26:11,654 - INFO - Inserting row into customers: ['24', 'Lisa Gutierrez', 'robinsonanthony@becker.com', '001-439-111-5955', '4']
# 2025-06-16 20:26:11,654 - INFO - Inserting row into customers: ['25', 'Tyler Perez', 'jeremylambert@sawyer.biz', '8637462561', '3']
# 2025-06-16 20:26:11,655 - INFO - Inserting row into customers: ['26', 'Ashley Henry', 'mary07@pittman-hunt.com', '487.257.4974', '4']
# 2025-06-16 20:26:11,655 - INFO - Inserting row into customers: ['27', 'Mrs. Laura Wallace', 'branchmegan@brown-gomez.com', '426-006-4646', '4']
# 2025-06-16 20:26:11,655 - INFO - Inserting row into customers: ['28', 'Alyssa Nunez', 'megan77@brown-medina.com', '001-948-243-7911x0946', '5']
# 2025-06-16 20:26:11,655 - INFO - Inserting row into customers: ['29', 'Dawn Austin', 'allenkelly@robinson-george.net', '955.570.7071', '4']
# 2025-06-16 20:26:11,657 - INFO - Inserting row into customers: ['30', 'Michael Adams', 'laurajenkins@hotmail.com', '200-928-0841x5035', '3']
# 2025-06-16 20:26:11,657 - INFO - Inserting row into customers: ['31', 'Steven Keith', 'gcarrillo@hotmail.com', '001-760-536-1352x633', '4']
# 2025-06-16 20:26:11,657 - INFO - Inserting row into customers: ['32', 'Angel Cannon', 'tgreene@gmail.com', '+1-133-854-5712x16422', '4']
# 2025-06-16 20:26:11,658 - INFO - Inserting row into customers: ['33', 'Sharon White', 'jrodriguez@santiago.com', '+1-092-097-5894x042', '1']
# 2025-06-16 20:26:11,658 - INFO - Inserting row into customers: ['34', 'Timothy Estes', 'ushepherd@wang.com', '837-115-0828x7649', '5']
# 2025-06-16 20:26:11,659 - INFO - Inserting row into customers: ['35', 'Paula Kemp', 'ilopez@hotmail.com', '(289)293-2750x220', '5']
# 2025-06-16 20:26:11,659 - INFO - Inserting row into customers: ['36', 'Elizabeth Stephens', 'cpena@yahoo.com', '(760)102-0959x697', '2']
# 2025-06-16 20:26:11,659 - INFO - Inserting row into customers: ['37', 'Timothy Shields MD', 'freemankristin@gmail.com', '581.372.6761', '1']
# 2025-06-16 20:26:11,660 - INFO - Inserting row into customers: ['38', 'William Young', 'spencertrevor@hotmail.com', '(138)510-5943', '5']
# 2025-06-16 20:26:11,660 - INFO - Inserting row into customers: ['39', 'Jocelyn Sullivan', 'michaelalvarado@gmail.com', '947-403-3899x051', '2']
# 2025-06-16 20:26:11,660 - INFO - Inserting row into customers: ['40', 'Lisa Fuller', 'christine95@barrera.com', '745-930-0558x589', '3']
# 2025-06-16 20:26:11,661 - INFO - Inserting row into customers: ['41', 'Robert Diaz', 'michaelhill@gmail.com', '825-647-3246x6451', '5']
# 2025-06-16 20:26:11,661 - INFO - Inserting row into customers: ['42', 'Stephanie Hall', 'martinkeith@hotmail.com', '853.916.0569x84968', '4']
# 2025-06-16 20:26:11,661 - INFO - Inserting row into customers: ['43', 'Samuel Mitchell', 'cmartin@hotmail.com', '693-803-5275x39158', '2']
# 2025-06-16 20:26:11,662 - INFO - Inserting row into customers: ['44', 'Alyssa Ramirez', 'danielanderson@baker-wang.net', '001-060-577-5821x25653', '5']
# 2025-06-16 20:26:11,662 - INFO - Inserting row into customers: ['45', 'Carolyn White', 'victoriahernandez@yahoo.com', '371.798.4018x4422', '5']
# 2025-06-16 20:26:11,662 - INFO - Inserting row into customers: ['46', 'Danielle Webster', 'susan33@yahoo.com', '+1-507-500-0401x677', '5']
# 2025-06-16 20:26:11,663 - INFO - Inserting row into customers: ['47', 'Bobby Wilcox', 'josephbrown@hotmail.com', '001-875-209-2627x09595', '5']
# 2025-06-16 20:26:11,663 - INFO - Inserting row into customers: ['48', 'Kristin Hanson', 'smills@yahoo.com', '001-762-595-6921x58182', '2']
# 2025-06-16 20:26:11,663 - INFO - Inserting row into customers: ['49', 'George Scott', 'steelenatalie@hotmail.com', '+1-958-643-2612', '2']
# 2025-06-16 20:26:11,664 - INFO - Inserting row into customers: ['50', 'Jessica Reynolds', 'ybaker@hotmail.com', '(519)700-2629', '5']
# 2025-06-16 20:26:11,664 - INFO - Inserting row into customers: ['51', 'Matthew Clark', 'mlopez@berger.com', '333-142-5030x928', '2']
# 2025-06-16 20:26:11,666 - INFO - Inserting row into customers: ['52', 'Andrea Brown', 'fisherzachary@thompson.net', '001-496-290-9113x24852', '5']
# 2025-06-16 20:26:11,666 - INFO - Inserting row into customers: ['53', 'Willie Ward', 'phutchinson@gmail.com', '(704)056-9398x02845', '2']
# 2025-06-16 20:26:11,667 - INFO - Inserting row into customers: ['54', 'Jacqueline Mccoy', 'margaret81@page.net', '969.004.6686x35000', '2']
# 2025-06-16 20:26:11,667 - INFO - Inserting row into customers: ['55', 'Jason Ortiz', 'matthewfischer@gmail.com', '(112)659-0911x11780', '3']
# 2025-06-16 20:26:11,667 - INFO - Inserting row into customers: ['56', 'Sarah Herrera', 'swallace@gmail.com', '+1-491-417-8618x5211', '4']
# 2025-06-16 20:26:11,668 - INFO - Inserting row into customers: ['57', 'Jason Bird', 'bramos@scott.net', '540.654.6239x6175', '4']
# 2025-06-16 20:26:11,668 - INFO - Inserting row into customers: ['58', 'Mrs. Whitney Edwards DDS', 'reneemclaughlin@gmail.com', '+1-582-626-3541x973', '4']
# 2025-06-16 20:26:11,669 - INFO - Inserting row into customers: ['59', 'David Jones', 'romeroangela@yahoo.com', '+1-547-237-7567x93662', '3']
# 2025-06-16 20:26:11,669 - INFO - Inserting row into customers: ['60', 'Ashley Lee', 'michealalexander@diaz-barron.info', '261.759.5086', '2']
# 2025-06-16 20:26:11,669 - INFO - Inserting row into customers: ['61', 'William Cooper', 'heatherbennett@sanders.com', '(615)726-7194x7201', '1']
# 2025-06-16 20:26:11,669 - INFO - Inserting row into customers: ['62', 'Christina Thompson', 'xsmith@evans.org', '+1-522-155-1967x8498', '4']
# 2025-06-16 20:26:11,670 - INFO - Inserting row into customers: ['63', 'Benjamin Martin', 'billycunningham@hotmail.com', '+1-932-484-2089x04687', '3']
# 2025-06-16 20:26:11,670 - INFO - Inserting row into customers: ['64', 'Tony Allen', 'fwilson@hotmail.com', '324.373.1915x5471', '1']
# 2025-06-16 20:26:11,671 - INFO - Inserting row into customers: ['65', 'Taylor Smith', 'melinda08@gmail.com', '770-304-8072', '3']
# 2025-06-16 20:26:11,671 - INFO - Inserting row into customers: ['66', 'Martin Andrade', 'maldonadodamon@morgan.com', '(347)726-3456x82741', '1']
# 2025-06-16 20:26:11,671 - INFO - Inserting row into customers: ['67', 'Anna Hall', 'steelebrian@gmail.com', '625.824.3330x551', '4']
# 2025-06-16 20:26:11,673 - INFO - Inserting row into customers: ['68', 'Donald Williams', 'allenlarry@owens-guerrero.com', '+1-125-142-9061', '1']
# 2025-06-16 20:26:11,674 - INFO - Inserting row into customers: ['69', 'Walter Randolph', 'bergkaren@richardson.com', '477.542.2164x02977', '4']
# 2025-06-16 20:26:11,674 - INFO - Inserting row into customers: ['70', 'Ryan Foster', 'lberg@reyes.com', '001-454-920-3178x57107', '4']
# 2025-06-16 20:26:11,674 - INFO - Inserting row into customers: ['71', 'Frank Hall', 'edwardmoore@mercado.net', '578-157-1870', '2']
# 2025-06-16 20:26:11,674 - INFO - Inserting row into customers: ['72', 'Steven Weaver', 'elizabeth73@yahoo.com', '+1-066-156-1090x4318', '3']
# 2025-06-16 20:26:11,675 - INFO - Inserting row into customers: ['73', 'Andrew Becker', 'ylewis@schroeder.info', '753-236-3900x203', '3']
# 2025-06-16 20:26:11,675 - INFO - Inserting row into customers: ['74', 'Amy Mason', 'huffmancatherine@gmail.com', '534-141-5928x7975', '4']
# 2025-06-16 20:26:11,675 - INFO - Inserting row into customers: ['75', 'Robert Green', 'hernandezrobert@phillips-adams.com', '+1-953-789-1111', '2']
# 2025-06-16 20:26:11,676 - INFO - Inserting row into customers: ['76', 'Jennifer Lucas', 'william07@gmail.com', '889-271-9927x6049', '1']
# 2025-06-16 20:26:11,676 - INFO - Inserting row into customers: ['77', 'Elizabeth Garcia', 'gary24@patterson.org', '001-292-242-6139x2389', '1']
# 2025-06-16 20:26:11,676 - INFO - Inserting row into customers: ['78', 'Alexander Davis', 'xtran@hotmail.com', '6852686474', '3']
# 2025-06-16 20:26:11,677 - INFO - Inserting row into customers: ['79', 'Teresa Lee', 'douglas62@gmail.com', '009.117.9376x84779', '3']
# 2025-06-16 20:26:11,677 - INFO - Inserting row into customers: ['80', 'Jason Waller', 'janice01@schmidt.info', '968-308-4950x362', '4']
# 2025-06-16 20:26:11,677 - INFO - Inserting row into customers: ['81', 'Brian Franklin', 'gonzalezelizabeth@king-gibbs.com', '3766382297', '3']
# 2025-06-16 20:26:11,679 - INFO - Inserting row into customers: ['82', 'Hailey Long', 'william31@williamson.net', '(798)463-9102x98637', '5']
# 2025-06-16 20:26:11,679 - INFO - Inserting row into customers: ['83', 'Katie Garcia', 'perezangelica@gmail.com', '(312)417-0122', '1']
# 2025-06-16 20:26:11,679 - INFO - Inserting row into customers: ['84', 'Denise Marsh', 'santiagorenee@hughes.com', '+1-834-789-4734x36006', '3']
# 2025-06-16 20:26:11,679 - INFO - Inserting row into customers: ['85', 'Mark Ramsey', 'riverajacob@harper-holmes.com', '001-485-357-2722', '4']
# 2025-06-16 20:26:11,680 - INFO - Inserting row into customers: ['86', 'Amy Kelley', 'jose25@hotmail.com', '+1-215-688-4892x6504', '2']
# 2025-06-16 20:26:11,681 - INFO - Inserting row into customers: ['87', 'Rachel David', 'debbie72@yahoo.com', '001-322-573-9865x099', '2']
# 2025-06-16 20:26:11,681 - INFO - Inserting row into customers: ['88', 'David Rogers', 'hernandezmichaela@pope.biz', '(440)136-7279', '4']
# 2025-06-16 20:26:11,681 - INFO - Inserting row into customers: ['89', 'Jessica Lee', 'robertsonmichael@hotmail.com', '663.423.0524', '5']
# 2025-06-16 20:26:11,683 - INFO - Inserting row into customers: ['90', 'Jennifer Weeks', 'rbutler@leonard-haney.com', '894-967-6486', '1']
# 2025-06-16 20:26:11,683 - INFO - Inserting row into customers: ['91', 'Joseph Smith', 'brianturner@murphy.com', '(171)877-9960', '4']
# 2025-06-16 20:26:11,683 - INFO - Inserting row into customers: ['92', 'Karen Thornton', 'erin61@woods.com', '+1-865-125-6096x3929', '4']
# 2025-06-16 20:26:11,684 - INFO - Inserting row into customers: ['93', 'Melissa Yang', 'riveratamara@hotmail.com', '800.414.7611x132', '2']
# 2025-06-16 20:26:11,684 - INFO - Inserting row into customers: ['94', 'Eric Garrison', 'fmccormick@hotmail.com', '(525)054-8972x0211', '1']
# 2025-06-16 20:26:11,685 - INFO - Inserting row into customers: ['95', 'Michelle Ochoa', 'christophermckinney@gmail.com', '727-564-2024x136', '5']
# 2025-06-16 20:26:11,685 - INFO - Inserting row into customers: ['96', 'Justin Cooper', 'michellebaker@marshall.net', '(115)523-7559x4231', '4']
# 2025-06-16 20:26:11,685 - INFO - Inserting row into customers: ['97', 'April Hull', 'jeremiahjohnson@hotmail.com', '(904)300-8615x9951', '2']
# 2025-06-16 20:26:11,686 - INFO - Inserting row into customers: ['98', 'Rachel Howell', 'andrewkrause@yahoo.com', '(983)387-8635', '2']
# 2025-06-16 20:26:11,686 - INFO - Inserting row into customers: ['99', 'James White', 'danderson@hotmail.com', '+1-501-119-9118x098', '4']
# 2025-06-16 20:26:11,687 - INFO - Inserting row into customers: ['100', 'Jennifer Walker', 'jessicalarson@morris.com', '001-510-750-8566x914', '2']
# Customers table created and data inserted successfully.
# 2025-06-16 20:26:13,777 - INFO - Inserting row into meters: ['1', '1', '2021-05-05']
# 2025-06-16 20:26:13,779 - INFO - Inserting row into meters: ['2', '2', '2020-11-05']
# 2025-06-16 20:26:13,780 - INFO - Inserting row into meters: ['3', '3', '2022-11-27']
# 2025-06-16 20:26:13,780 - INFO - Inserting row into meters: ['4', '4', '2022-02-26']
# 2025-06-16 20:26:13,781 - INFO - Inserting row into meters: ['5', '5', '2022-07-04']
# 2025-06-16 20:26:13,781 - INFO - Inserting row into meters: ['6', '6', '2024-10-15']
# 2025-06-16 20:26:13,782 - INFO - Inserting row into meters: ['7', '7', '2020-07-24']
# 2025-06-16 20:26:13,782 - INFO - Inserting row into meters: ['8', '8', '2021-11-17']
# 2025-06-16 20:26:13,783 - INFO - Inserting row into meters: ['9', '9', '2023-09-17']
# 2025-06-16 20:26:13,783 - INFO - Inserting row into meters: ['10', '10', '2024-02-25']
# 2025-06-16 20:26:13,784 - INFO - Inserting row into meters: ['11', '11', '2022-02-09']
# 2025-06-16 20:26:13,784 - INFO - Inserting row into meters: ['12', '12', '2024-05-08']
# 2025-06-16 20:26:13,785 - INFO - Inserting row into meters: ['13', '13', '2024-03-27']
# 2025-06-16 20:26:13,785 - INFO - Inserting row into meters: ['14', '14', '2020-12-25']
# 2025-06-16 20:26:13,785 - INFO - Inserting row into meters: ['15', '15', '2024-12-11']
# 2025-06-16 20:26:13,786 - INFO - Inserting row into meters: ['16', '16', '2021-10-11']
# 2025-06-16 20:26:13,786 - INFO - Inserting row into meters: ['17', '17', '2023-06-04']
# 2025-06-16 20:26:13,787 - INFO - Inserting row into meters: ['18', '18', '2025-02-09']
# 2025-06-16 20:26:13,787 - INFO - Inserting row into meters: ['19', '19', '2022-09-04']
# 2025-06-16 20:26:13,787 - INFO - Inserting row into meters: ['20', '20', '2023-10-30']
# 2025-06-16 20:26:13,788 - INFO - Inserting row into meters: ['21', '21', '2025-01-03']
# 2025-06-16 20:26:13,788 - INFO - Inserting row into meters: ['22', '22', '2020-06-16']
# 2025-06-16 20:26:13,788 - INFO - Inserting row into meters: ['23', '23', '2024-11-16']
# 2025-06-16 20:26:13,790 - INFO - Inserting row into meters: ['24', '24', '2021-01-28']
# 2025-06-16 20:26:13,790 - INFO - Inserting row into meters: ['25', '25', '2025-02-17']
# 2025-06-16 20:26:13,790 - INFO - Inserting row into meters: ['26', '26', '2021-04-20']
# 2025-06-16 20:26:13,791 - INFO - Inserting row into meters: ['27', '27', '2021-11-04']
# 2025-06-16 20:26:13,791 - INFO - Inserting row into meters: ['28', '28', '2024-12-11']
# 2025-06-16 20:26:13,792 - INFO - Inserting row into meters: ['29', '29', '2022-08-09']
# 2025-06-16 20:26:13,792 - INFO - Inserting row into meters: ['30', '30', '2022-11-22']
# 2025-06-16 20:26:13,792 - INFO - Inserting row into meters: ['31', '31', '2023-10-09']
# 2025-06-16 20:26:13,793 - INFO - Inserting row into meters: ['32', '32', '2022-07-27']
# 2025-06-16 20:26:13,793 - INFO - Inserting row into meters: ['33', '33', '2024-09-19']
# 2025-06-16 20:26:13,794 - INFO - Inserting row into meters: ['34', '34', '2023-01-06']
# 2025-06-16 20:26:13,794 - INFO - Inserting row into meters: ['35', '35', '2022-12-15']
# 2025-06-16 20:26:13,796 - INFO - Inserting row into meters: ['36', '36', '2021-07-24']
# 2025-06-16 20:26:13,796 - INFO - Inserting row into meters: ['37', '37', '2020-07-21']
# 2025-06-16 20:26:13,797 - INFO - Inserting row into meters: ['38', '38', '2023-03-08']
# 2025-06-16 20:26:13,797 - INFO - Inserting row into meters: ['39', '39', '2021-11-17']
# 2025-06-16 20:26:13,797 - INFO - Inserting row into meters: ['40', '40', '2021-07-03']
# 2025-06-16 20:26:13,798 - INFO - Inserting row into meters: ['41', '41', '2022-10-19']
# 2025-06-16 20:26:13,798 - INFO - Inserting row into meters: ['42', '42', '2021-08-07']
# 2025-06-16 20:26:13,799 - INFO - Inserting row into meters: ['43', '43', '2021-04-03']
# 2025-06-16 20:26:13,799 - INFO - Inserting row into meters: ['44', '44', '2023-12-01']
# 2025-06-16 20:26:13,799 - INFO - Inserting row into meters: ['45', '45', '2021-03-16']
# 2025-06-16 20:26:13,799 - INFO - Inserting row into meters: ['46', '46', '2024-01-16']
# 2025-06-16 20:26:13,800 - INFO - Inserting row into meters: ['47', '47', '2024-08-14']
# 2025-06-16 20:26:13,800 - INFO - Inserting row into meters: ['48', '48', '2024-09-01']
# 2025-06-16 20:26:13,800 - INFO - Inserting row into meters: ['49', '49', '2022-10-28']
# 2025-06-16 20:26:13,801 - INFO - Inserting row into meters: ['50', '50', '2020-09-30']
# 2025-06-16 20:26:13,801 - INFO - Inserting row into meters: ['51', '51', '2025-04-27']
# 2025-06-16 20:26:13,802 - INFO - Inserting row into meters: ['52', '52', '2020-12-28']
# 2025-06-16 20:26:13,802 - INFO - Inserting row into meters: ['53', '53', '2022-03-31']
# 2025-06-16 20:26:13,802 - INFO - Inserting row into meters: ['54', '54', '2024-02-18']
# 2025-06-16 20:26:13,803 - INFO - Inserting row into meters: ['55', '55', '2021-11-18']
# 2025-06-16 20:26:13,803 - INFO - Inserting row into meters: ['56', '56', '2025-06-14']
# 2025-06-16 20:26:13,804 - INFO - Inserting row into meters: ['57', '57', '2021-10-19']
# 2025-06-16 20:26:13,804 - INFO - Inserting row into meters: ['58', '58', '2022-06-10']
# 2025-06-16 20:26:13,804 - INFO - Inserting row into meters: ['59', '59', '2020-11-09']
# 2025-06-16 20:26:13,805 - INFO - Inserting row into meters: ['60', '60', '2024-04-14']
# 2025-06-16 20:26:13,805 - INFO - Inserting row into meters: ['61', '61', '2024-04-14']
# 2025-06-16 20:26:13,806 - INFO - Inserting row into meters: ['62', '62', '2022-07-05']
# 2025-06-16 20:26:13,806 - INFO - Inserting row into meters: ['63', '63', '2024-07-10']
# 2025-06-16 20:26:13,806 - INFO - Inserting row into meters: ['64', '64', '2022-06-05']
# 2025-06-16 20:26:13,807 - INFO - Inserting row into meters: ['65', '65', '2020-10-14']
# 2025-06-16 20:26:13,807 - INFO - Inserting row into meters: ['66', '66', '2024-04-08']
# 2025-06-16 20:26:13,808 - INFO - Inserting row into meters: ['67', '67', '2024-04-16']
# 2025-06-16 20:26:13,808 - INFO - Inserting row into meters: ['68', '68', '2021-04-19']
# 2025-06-16 20:26:13,808 - INFO - Inserting row into meters: ['69', '69', '2021-12-05']
# 2025-06-16 20:26:13,808 - INFO - Inserting row into meters: ['70', '70', '2022-01-30']
# 2025-06-16 20:26:13,810 - INFO - Inserting row into meters: ['71', '71', '2020-07-18']
# 2025-06-16 20:26:13,810 - INFO - Inserting row into meters: ['72', '72', '2021-12-04']
# 2025-06-16 20:26:13,810 - INFO - Inserting row into meters: ['73', '73', '2021-08-06']
# 2025-06-16 20:26:13,811 - INFO - Inserting row into meters: ['74', '74', '2025-01-08']
# 2025-06-16 20:26:13,811 - INFO - Inserting row into meters: ['75', '75', '2023-09-07']
# 2025-06-16 20:26:13,812 - INFO - Inserting row into meters: ['76', '76', '2021-12-20']
# 2025-06-16 20:26:13,812 - INFO - Inserting row into meters: ['77', '77', '2025-04-10']
# 2025-06-16 20:26:13,813 - INFO - Inserting row into meters: ['78', '78', '2021-10-09']
# 2025-06-16 20:26:13,813 - INFO - Inserting row into meters: ['79', '79', '2023-04-30']
# 2025-06-16 20:26:13,813 - INFO - Inserting row into meters: ['80', '80', '2022-05-08']
# 2025-06-16 20:26:13,814 - INFO - Inserting row into meters: ['81', '81', '2021-09-19']
# 2025-06-16 20:26:13,814 - INFO - Inserting row into meters: ['82', '82', '2021-07-02']
# 2025-06-16 20:26:13,815 - INFO - Inserting row into meters: ['83', '83', '2025-03-31']
# 2025-06-16 20:26:13,815 - INFO - Inserting row into meters: ['84', '84', '2024-04-01']
# 2025-06-16 20:26:13,815 - INFO - Inserting row into meters: ['85', '85', '2021-02-15']
# 2025-06-16 20:26:13,816 - INFO - Inserting row into meters: ['86', '86', '2024-10-08']
# 2025-06-16 20:26:13,817 - INFO - Inserting row into meters: ['87', '87', '2025-01-05']
# 2025-06-16 20:26:13,817 - INFO - Inserting row into meters: ['88', '88', '2024-11-05']
# 2025-06-16 20:26:13,817 - INFO - Inserting row into meters: ['89', '89', '2025-02-26']
# 2025-06-16 20:26:13,818 - INFO - Inserting row into meters: ['90', '90', '2025-02-05']
# 2025-06-16 20:26:13,818 - INFO - Inserting row into meters: ['91', '91', '2024-01-20']
# 2025-06-16 20:26:13,819 - INFO - Inserting row into meters: ['92', '92', '2021-11-10']
# 2025-06-16 20:26:13,819 - INFO - Inserting row into meters: ['93', '93', '2023-04-09']
# 2025-06-16 20:26:13,819 - INFO - Inserting row into meters: ['94', '94', '2024-02-18']
# 2025-06-16 20:26:13,820 - INFO - Inserting row into meters: ['95', '95', '2023-05-17']
# 2025-06-16 20:26:13,820 - INFO - Inserting row into meters: ['96', '96', '2025-04-01']
# 2025-06-16 20:26:13,820 - INFO - Inserting row into meters: ['97', '97', '2025-01-02']
# 2025-06-16 20:26:13,820 - INFO - Inserting row into meters: ['98', '98', '2021-08-20']
# 2025-06-16 20:26:13,821 - INFO - Inserting row into meters: ['99', '99', '2025-01-08']
# 2025-06-16 20:26:13,821 - INFO - Inserting row into meters: ['100', '100', '2020-07-03']
# Meters table created and data inserted successfully.
# 2025-06-16 20:26:15,871 - INFO - Inserting row into billing: ['c806b4bd-3315-48a6-9334-065a1be4cd1a', '1', '2025-03-30', '2968.67', 'unpaid']
# 2025-06-16 20:26:15,873 - INFO - Inserting row into billing: ['b31d092b-1443-4216-adbd-e2e6ea6ffc8c', '1', '2025-03-17', '2575.74', 'paid']
# 2025-06-16 20:26:15,873 - INFO - Inserting row into billing: ['46e3e340-e91c-4b21-ae41-9690277e6225', '1', '2025-05-11', '2378.87', 'unpaid']
# 2025-06-16 20:26:15,874 - INFO - Inserting row into billing: ['7b441018-78a4-4c72-85ec-0e50972f37e4', '2', '2025-05-05', '557.22', 'unpaid']
# 2025-06-16 20:26:15,874 - INFO - Inserting row into billing: ['34d18187-924c-446c-86b5-44727d2904c7', '2', '2025-04-22', '812.19', 'paid']
# 2025-06-16 20:26:15,875 - INFO - Inserting row into billing: ['b872dcfd-3c2f-46ae-b6df-571fe6134b2f', '2', '2025-05-03', '1663.33', 'unpaid']
# 2025-06-16 20:26:15,875 - INFO - Inserting row into billing: ['222820cc-b19e-46e9-acf5-6ae1e20a1b53', '3', '2025-05-03', '1179.48', 'paid']
# 2025-06-16 20:26:15,876 - INFO - Inserting row into billing: ['bc735245-2207-4c02-94b7-4e92be9d2666', '3', '2025-04-10', '2867.81', 'unpaid']
# 2025-06-16 20:26:15,876 - INFO - Inserting row into billing: ['687a55d9-893c-40b8-9791-5f40e4da8a85', '3', '2025-03-20', '1358.39', 'unpaid']
# 2025-06-16 20:26:15,877 - INFO - Inserting row into billing: ['6dd2487c-5d5b-4687-9026-0dda804c471c', '4', '2025-03-20', '2956.41', 'paid']
# 2025-06-16 20:26:15,877 - INFO - Inserting row into billing: ['ad874be4-a442-47be-96b8-531dddcbf3b8', '4', '2025-05-31', '2052.05', 'paid']
# 2025-06-16 20:26:15,878 - INFO - Inserting row into billing: ['7c24f393-e47c-4656-9826-d35de1edf563', '4', '2025-05-23', '566.9', 'unpaid']
# 2025-06-16 20:26:15,878 - INFO - Inserting row into billing: ['a2121864-5e79-4652-88cd-f3750a038fa5', '5', '2025-06-02', '2066.54', 'unpaid']
# 2025-06-16 20:26:15,878 - INFO - Inserting row into billing: ['70d8c9f1-13b5-4832-82d7-83ba827273f6', '5', '2025-04-28', '1741.64', 'paid']
# 2025-06-16 20:26:15,880 - INFO - Inserting row into billing: ['7d972572-36f0-491f-8ca4-c7d0fb762110', '5', '2025-04-08', '2740.45', 'unpaid']
# 2025-06-16 20:26:15,880 - INFO - Inserting row into billing: ['97b0785f-80b9-4adf-8606-b55e3c8e7e2f', '6', '2025-05-22', '1430.33', 'paid']
# 2025-06-16 20:26:15,881 - INFO - Inserting row into billing: ['61845faf-3eb5-4005-a8f7-9bb1e95721ec', '6', '2025-06-05', '635.05', 'paid']
# 2025-06-16 20:26:15,881 - INFO - Inserting row into billing: ['e489b497-4239-4252-8e48-1a0e5ab22916', '6', '2025-05-14', '2320.03', 'unpaid']
# 2025-06-16 20:26:15,882 - INFO - Inserting row into billing: ['eae7aa8f-ebd2-4d8d-a72d-b15cb87098fc', '7', '2025-05-14', '1030.87', 'paid']
# 2025-06-16 20:26:15,882 - INFO - Inserting row into billing: ['d2d87e59-b79d-46a5-9c3d-b526427849f9', '7', '2025-05-04', '2458.78', 'unpaid']
# 2025-06-16 20:26:15,882 - INFO - Inserting row into billing: ['04b57c16-9220-4048-8515-07f149ac1462', '7', '2025-04-23', '1233.36', 'paid']
# 2025-06-16 20:26:15,883 - INFO - Inserting row into billing: ['9c249eee-d6c7-40ed-ac46-d089d949b5c7', '8', '2025-06-14', '2889.24', 'paid']
# 2025-06-16 20:26:15,883 - INFO - Inserting row into billing: ['e12599ff-4658-4480-b210-34d46805e085', '8', '2025-04-12', '2397.66', 'unpaid']
# 2025-06-16 20:26:15,884 - INFO - Inserting row into billing: ['0f3de3c0-d102-41f6-803a-c7514b09e259', '8', '2025-05-12', '2684.56', 'unpaid']
# 2025-06-16 20:26:15,884 - INFO - Inserting row into billing: ['ab30e3a0-89f9-47e6-98e1-199f2bb29d4e', '9', '2025-05-25', '1574.16', 'paid']
# 2025-06-16 20:26:15,885 - INFO - Inserting row into billing: ['df863481-649c-465e-8986-d24c634a5409', '9', '2025-03-18', '664.46', 'unpaid']
# 2025-06-16 20:26:15,886 - INFO - Inserting row into billing: ['8958b210-dca3-4f5a-b46c-ced06b535985', '9', '2025-04-09', '1459.68', 'unpaid']
# 2025-06-16 20:26:15,887 - INFO - Inserting row into billing: ['4806b71a-7573-428d-89c4-fb17b183f789', '10', '2025-05-07', '2994.54', 'paid']
# 2025-06-16 20:26:15,887 - INFO - Inserting row into billing: ['475924a0-1d4a-4757-aa86-9726e59f056c', '10', '2025-06-07', '2200.18', 'unpaid']
# 2025-06-16 20:26:15,888 - INFO - Inserting row into billing: ['535ff649-ab0a-410a-a658-13ddc913ad8e', '10', '2025-05-24', '1207.84', 'paid']
# 2025-06-16 20:26:15,888 - INFO - Inserting row into billing: ['247d9ae1-590a-4ceb-9107-bddc601c88c0', '11', '2025-06-05', '1018.19', 'unpaid']
# 2025-06-16 20:26:15,888 - INFO - Inserting row into billing: ['199acd26-b0cc-4334-ac05-f931cab8c5e7', '11', '2025-05-07', '2286.5', 'unpaid']
# 2025-06-16 20:26:15,890 - INFO - Inserting row into billing: ['8dad2f67-08d7-49ba-81de-8629a8e3d0a2', '11', '2025-05-26', '1475.23', 'unpaid']
# 2025-06-16 20:26:15,890 - INFO - Inserting row into billing: ['e0717e4b-34ef-439d-8bbf-1ee4fe912bdc', '12', '2025-05-11', '1258.33', 'paid']
# 2025-06-16 20:26:15,891 - INFO - Inserting row into billing: ['0f7130f7-8a9c-4787-aa70-38fd7a40b605', '12', '2025-03-28', '1125.35', 'paid']
# 2025-06-16 20:26:15,891 - INFO - Inserting row into billing: ['62f6998b-3e11-49c6-bc5b-98cc3635d419', '12', '2025-05-25', '830.25', 'paid']
# 2025-06-16 20:26:15,892 - INFO - Inserting row into billing: ['23a7c7d3-128d-4b75-9be7-1f8d50c3d228', '13', '2025-04-10', '1023.47', 'paid']
# 2025-06-16 20:26:15,892 - INFO - Inserting row into billing: ['b751df28-daa7-443a-9374-42bec743d9b6', '13', '2025-06-14', '1909.12', 'unpaid']
# 2025-06-16 20:26:15,893 - INFO - Inserting row into billing: ['593afac8-a826-47ad-815b-bad5649e0f73', '13', '2025-04-30', '2769.13', 'paid']
# 2025-06-16 20:26:15,893 - INFO - Inserting row into billing: ['f88d7745-3e62-4df2-bdfb-7e76915d2f62', '14', '2025-05-03', '1042.1', 'paid']
# 2025-06-16 20:26:15,894 - INFO - Inserting row into billing: ['91a3acd9-0f0a-45ee-9a22-24b5fb1640dc', '14', '2025-05-24', '2113.93', 'unpaid']
# 2025-06-16 20:26:15,894 - INFO - Inserting row into billing: ['2ee41546-e84e-4e34-85f1-41596298666f', '14', '2025-04-04', '1432.17', 'unpaid']
# 2025-06-16 20:26:15,894 - INFO - Inserting row into billing: ['9cd9a05e-7023-40f8-aa52-00ec74436565', '15', '2025-06-15', '2597.89', 'paid']
# 2025-06-16 20:26:15,895 - INFO - Inserting row into billing: ['ccc72371-23cd-46a5-b490-0f3f11ece42b', '15', '2025-05-21', '2202.46', 'paid']
# 2025-06-16 20:26:15,895 - INFO - Inserting row into billing: ['18e632c0-0924-4fd7-8540-64a33d2511e2', '15', '2025-04-22', '1178.14', 'unpaid']
# 2025-06-16 20:26:15,897 - INFO - Inserting row into billing: ['92afab5c-dace-4486-8c53-9f767bc5be00', '16', '2025-03-30', '1577.21', 'unpaid']
# 2025-06-16 20:26:15,897 - INFO - Inserting row into billing: ['8d18333d-6b64-4e5c-99f3-6b47ed6c6702', '16', '2025-05-05', '2425.23', 'paid']
# 2025-06-16 20:26:15,898 - INFO - Inserting row into billing: ['3a17bb38-eb90-4d46-a71d-220902cfa38e', '16', '2025-05-30', '1564.28', 'unpaid']
# 2025-06-16 20:26:15,898 - INFO - Inserting row into billing: ['e4dab2c4-7590-4895-bf85-20388a1ac109', '17', '2025-04-29', '1809.54', 'paid']
# 2025-06-16 20:26:15,898 - INFO - Inserting row into billing: ['043bdcc2-fa8b-45f4-a40a-ef88b9c9bd46', '17', '2025-05-12', '2880.37', 'unpaid']
# 2025-06-16 20:26:15,899 - INFO - Inserting row into billing: ['da071cca-efad-48ea-83ee-f02647260518', '17', '2025-06-10', '2760.35', 'paid']
# 2025-06-16 20:26:15,899 - INFO - Inserting row into billing: ['5f2b6654-26c1-4d30-8522-9b0f5b016f19', '18', '2025-04-01', '2254.87', 'unpaid']
# 2025-06-16 20:26:15,899 - INFO - Inserting row into billing: ['c983a502-a4db-4185-82bf-6c680e836815', '18', '2025-05-28', '1104.83', 'unpaid']
# 2025-06-16 20:26:15,900 - INFO - Inserting row into billing: ['3120cb10-3011-4a24-8332-83e67f87ffaf', '18', '2025-05-21', '2896.81', 'paid']
# 2025-06-16 20:26:15,901 - INFO - Inserting row into billing: ['b1c1932c-afe1-4d0a-81b0-6d99375dc4d8', '19', '2025-04-12', '865.6', 'paid']
# 2025-06-16 20:26:15,901 - INFO - Inserting row into billing: ['3e8e9054-f8ab-4a81-b6e7-10d12cd0f550', '19', '2025-06-04', '1615.41', 'unpaid']
# 2025-06-16 20:26:15,902 - INFO - Inserting row into billing: ['119bda64-b8ad-4cf5-967f-3a3b7c88e770', '19', '2025-05-11', '1249.41', 'paid']
# 2025-06-16 20:26:15,903 - INFO - Inserting row into billing: ['2a5ab47f-6d88-4a07-8b13-500a0efec073', '20', '2025-04-25', '1428.54', 'paid']
# 2025-06-16 20:26:15,903 - INFO - Inserting row into billing: ['18e7f14a-5260-42cf-9bf9-72cdde6fa126', '20', '2025-05-01', '2385.66', 'unpaid']
# 2025-06-16 20:26:15,904 - INFO - Inserting row into billing: ['ca2b0891-60cf-44fd-b169-c470da645a49', '20', '2025-04-12', '1068.47', 'paid']
# 2025-06-16 20:26:15,904 - INFO - Inserting row into billing: ['f2fafc9f-57c9-4827-ba09-f61dc2f57ce0', '21', '2025-05-01', '1277.5', 'unpaid']
# 2025-06-16 20:26:15,904 - INFO - Inserting row into billing: ['4567abe7-e5bd-4957-8884-5d6d94ec3868', '21', '2025-04-21', '2984.23', 'paid']
# 2025-06-16 20:26:15,905 - INFO - Inserting row into billing: ['7c4b535f-94cf-4158-bc5b-92032f663b1a', '21', '2025-03-21', '1625.16', 'paid']
# 2025-06-16 20:26:15,905 - INFO - Inserting row into billing: ['5e8d0c57-ae46-4398-a71f-896e05b6e1c5', '22', '2025-06-07', '704.38', 'paid']
# 2025-06-16 20:26:15,906 - INFO - Inserting row into billing: ['5606fa39-da5e-4378-a111-562914f7d69b', '22', '2025-05-03', '2343.79', 'paid']
# 2025-06-16 20:26:15,906 - INFO - Inserting row into billing: ['f7a3c49f-c27d-4f3d-96b7-0fc5ea1fe7ae', '22', '2025-05-09', '998.12', 'unpaid']
# 2025-06-16 20:26:15,908 - INFO - Inserting row into billing: ['c9ec290c-1313-48ab-a871-4931d921c27b', '23', '2025-05-25', '2865.23', 'unpaid']
# 2025-06-16 20:26:15,908 - INFO - Inserting row into billing: ['e1a958e3-7afa-49c7-8149-81e89669b801', '23', '2025-05-25', '2110.09', 'unpaid']
# 2025-06-16 20:26:15,908 - INFO - Inserting row into billing: ['8062dc52-0b0c-4b48-8848-0c3a72ed2e5b', '23', '2025-04-18', '1901.21', 'paid']
# 2025-06-16 20:26:15,909 - INFO - Inserting row into billing: ['ec5effd2-dca7-4f15-a91d-ab9efa72e95a', '24', '2025-03-25', '2615.14', 'unpaid']
# 2025-06-16 20:26:15,909 - INFO - Inserting row into billing: ['ce096eba-f882-4145-9251-35e13730dcb3', '24', '2025-03-27', '2442.52', 'unpaid']
# 2025-06-16 20:26:15,910 - INFO - Inserting row into billing: ['2d9f57af-bcf4-4943-8bee-668909d0b82f', '24', '2025-06-07', '1063.46', 'paid']
# 2025-06-16 20:26:15,910 - INFO - Inserting row into billing: ['8c88695c-1c8f-45e8-ad65-53494c2ee2d0', '25', '2025-05-02', '712.63', 'paid']
# 2025-06-16 20:26:15,911 - INFO - Inserting row into billing: ['d6b99762-8cca-49b8-b953-c7eeb483d508', '25', '2025-04-08', '1730.63', 'paid']
# 2025-06-16 20:26:15,911 - INFO - Inserting row into billing: ['abc60bd9-3425-462c-83e3-535ed5da872f', '25', '2025-06-04', '2079.77', 'paid']
# 2025-06-16 20:26:15,912 - INFO - Inserting row into billing: ['e6c175f9-93e0-4674-9cdb-c0408d8b4791', '26', '2025-04-19', '1181.28', 'unpaid']
# 2025-06-16 20:26:15,912 - INFO - Inserting row into billing: ['261d8da6-6104-415f-ad2c-0840cd1c0d58', '26', '2025-06-01', '1074.52', 'unpaid']
# 2025-06-16 20:26:15,913 - INFO - Inserting row into billing: ['a4c23f79-b029-434e-905c-c4258970e40b', '26', '2025-06-13', '889.54', 'unpaid']
# 2025-06-16 20:26:15,913 - INFO - Inserting row into billing: ['ba6b33a0-812b-4876-9c50-24eb11b13174', '27', '2025-06-13', '2908.94', 'unpaid']
# 2025-06-16 20:26:15,914 - INFO - Inserting row into billing: ['bbcf05e1-2a76-43bd-9200-8ad960d485d1', '27', '2025-04-06', '571.93', 'paid']
# 2025-06-16 20:26:15,914 - INFO - Inserting row into billing: ['8ff3671e-9a17-4e8c-972a-3ea9111d1b27', '27', '2025-04-07', '1485.34', 'unpaid']
# 2025-06-16 20:26:15,914 - INFO - Inserting row into billing: ['edd0deab-aa47-4f6c-8c25-7a3306b46bd2', '28', '2025-04-09', '928.45', 'paid']
# 2025-06-16 20:26:15,915 - INFO - Inserting row into billing: ['bee92674-cd86-4bd3-a7d9-8bdfb71431bd', '28', '2025-04-30', '1446.33', 'unpaid']
# 2025-06-16 20:26:15,916 - INFO - Inserting row into billing: ['8b704f11-9b10-4763-8171-91fc07e284ec', '28', '2025-04-28', '2364.54', 'unpaid']
# 2025-06-16 20:26:15,916 - INFO - Inserting row into billing: ['2f51f0a5-3142-4e10-8243-b37a8985e47d', '29', '2025-06-14', '606.07', 'paid']
# 2025-06-16 20:26:15,917 - INFO - Inserting row into billing: ['56011eed-fb4e-4b26-89b7-bb2c7d251a24', '29', '2025-03-18', '1781.7', 'paid']
# 2025-06-16 20:26:15,917 - INFO - Inserting row into billing: ['024d8f8a-0bfc-46bb-831c-6ac6691bf4ec', '29', '2025-05-17', '2551.19', 'unpaid']
# 2025-06-16 20:26:15,918 - INFO - Inserting row into billing: ['0c0c2f58-4e7c-46e7-b58f-094f40e857b8', '30', '2025-05-21', '1569.12', 'paid']
# 2025-06-16 20:26:15,918 - INFO - Inserting row into billing: ['528a12b2-f595-4b40-ae97-242497c23816', '30', '2025-04-10', '1013.88', 'paid']
# 2025-06-16 20:26:15,918 - INFO - Inserting row into billing: ['bde382c3-c237-48d3-93ab-76d2c3729096', '30', '2025-06-04', '1025.87', 'paid']
# 2025-06-16 20:26:15,920 - INFO - Inserting row into billing: ['9f12a7bf-2589-4263-9196-aa2d54fab42f', '31', '2025-04-13', '2943.08', 'paid']
# 2025-06-16 20:26:15,920 - INFO - Inserting row into billing: ['86f8c4c1-84b3-4299-8671-44c1ab3beae5', '31', '2025-04-18', '2068.83', 'unpaid']
# 2025-06-16 20:26:15,921 - INFO - Inserting row into billing: ['a82b3fb4-8735-4bce-b444-9ea3a061ec05', '31', '2025-06-10', '2491.11', 'paid']
# 2025-06-16 20:26:15,921 - INFO - Inserting row into billing: ['467a2232-2fde-4ecf-9a1b-460477fda14f', '32', '2025-04-29', '2825.29', 'unpaid']
# 2025-06-16 20:26:15,922 - INFO - Inserting row into billing: ['7013eba3-e1c9-498d-a8e3-7de6e4f854d0', '32', '2025-06-05', '839.11', 'paid']
# 2025-06-16 20:26:15,922 - INFO - Inserting row into billing: ['e9e8b9c1-845f-4871-bb3d-24be48cb703c', '32', '2025-05-10', '1148.19', 'paid']
# 2025-06-16 20:26:15,923 - INFO - Inserting row into billing: ['bb7b32d7-2050-4620-81b7-c9af343e508a', '33', '2025-05-13', '1372.97', 'paid']
# 2025-06-16 20:26:15,923 - INFO - Inserting row into billing: ['adb7e1f4-ddd5-4292-bd78-d79a866d843b', '33', '2025-05-08', '2792.26', 'unpaid']
# 2025-06-16 20:26:15,923 - INFO - Inserting row into billing: ['1fcef800-64e0-4b7b-acdd-d5afb5b39272', '33', '2025-04-09', '2752.56', 'paid']
# 2025-06-16 20:26:15,924 - INFO - Inserting row into billing: ['5bc1a68e-eb64-46ab-ad3b-c57def05fbf7', '34', '2025-03-22', '1026.75', 'unpaid']
# 2025-06-16 20:26:15,924 - INFO - Inserting row into billing: ['93bbd687-e388-4a20-9ac1-217d941c24cf', '34', '2025-05-03', '2931.53', 'paid']
# 2025-06-16 20:26:15,925 - INFO - Inserting row into billing: ['fe8dacb6-eecd-421b-bb12-bd1d52e90596', '34', '2025-06-03', '2144.46', 'paid']
# 2025-06-16 20:26:15,925 - INFO - Inserting row into billing: ['ce23e773-1ea5-4d91-abc2-ee7e5b0d4e50', '35', '2025-06-14', '512.79', 'unpaid']
# 2025-06-16 20:26:15,926 - INFO - Inserting row into billing: ['d55fbb6a-d109-4ae2-8eff-c861ffa4b29c', '35', '2025-03-30', '2107.98', 'paid']
# 2025-06-16 20:26:15,926 - INFO - Inserting row into billing: ['bda6844f-8912-4311-8dcd-621fee13e8bd', '35', '2025-03-22', '1313.96', 'unpaid']
# 2025-06-16 20:26:15,926 - INFO - Inserting row into billing: ['b35880e6-32e9-4531-a54d-509b0961055d', '36', '2025-04-11', '2983.62', 'unpaid']
# 2025-06-16 20:26:15,927 - INFO - Inserting row into billing: ['26f31341-8aec-4b7b-b407-eb04d862bcb6', '36', '2025-04-08', '901.42', 'unpaid']
# 2025-06-16 20:26:15,927 - INFO - Inserting row into billing: ['643e3a8b-90b6-41fa-a483-4cf7c68e1354', '36', '2025-06-03', '2700.62', 'paid']
# 2025-06-16 20:26:15,927 - INFO - Inserting row into billing: ['b036fa90-2018-44c7-a517-f23fa12d3f3b', '37', '2025-06-09', '894.94', 'paid']
# 2025-06-16 20:26:15,929 - INFO - Inserting row into billing: ['06ef2fbb-0865-4273-bb2f-bb62553be687', '37', '2025-03-28', '1267.41', 'paid']
# 2025-06-16 20:26:15,929 - INFO - Inserting row into billing: ['b0ff8451-f626-4e21-a8b9-6ce2990a2beb', '37', '2025-04-23', '2061.03', 'paid']
# 2025-06-16 20:26:15,930 - INFO - Inserting row into billing: ['e46002eb-2b5f-4c32-aab2-e61bc336fa2e', '38', '2025-04-01', '553.37', 'unpaid']
# 2025-06-16 20:26:15,930 - INFO - Inserting row into billing: ['0c8f2efa-f8e3-4048-8e1b-b8e8677a3416', '38', '2025-06-11', '1780.4', 'unpaid']
# 2025-06-16 20:26:15,930 - INFO - Inserting row into billing: ['e05960cf-1ff0-4ca9-bba5-efdc061f1d0b', '38', '2025-03-18', '1448.57', 'unpaid']
# 2025-06-16 20:26:15,931 - INFO - Inserting row into billing: ['57e71620-ec5c-4f2f-950c-b02c4f0f26b3', '39', '2025-04-30', '2102.45', 'paid']
# 2025-06-16 20:26:15,931 - INFO - Inserting row into billing: ['663fbbf8-b7a8-448b-a37d-a6ff28a65242', '39', '2025-03-31', '1314.6', 'paid']
# 2025-06-16 20:26:15,932 - INFO - Inserting row into billing: ['c37b9fbd-2cfb-4b67-b87f-e2b70623530c', '39', '2025-04-04', '2063.73', 'paid']
# 2025-06-16 20:26:15,932 - INFO - Inserting row into billing: ['89bc24f7-5182-4290-b57e-01a8c3e62c64', '40', '2025-05-23', '1986.76', 'paid']
# 2025-06-16 20:26:15,933 - INFO - Inserting row into billing: ['efad72a0-b9bd-48f6-9953-703e9b1b59ce', '40', '2025-05-10', '663.7', 'paid']
# 2025-06-16 20:26:15,933 - INFO - Inserting row into billing: ['48e33220-1f82-4c83-b5f5-dac8398de682', '40', '2025-04-03', '2216.22', 'unpaid']
# 2025-06-16 20:26:15,934 - INFO - Inserting row into billing: ['941f918d-70ff-44f0-91d8-06f3b386320d', '41', '2025-05-18', '2941.7', 'unpaid']
# 2025-06-16 20:26:15,934 - INFO - Inserting row into billing: ['f7a26aae-c726-4635-8c3a-3e2c34492ff3', '41', '2025-06-14', '886.73', 'unpaid']
# 2025-06-16 20:26:15,936 - INFO - Inserting row into billing: ['df82b0c7-a40f-4c36-ab01-6344e9ffe969', '41', '2025-04-16', '509.31', 'unpaid']
# 2025-06-16 20:26:15,936 - INFO - Inserting row into billing: ['0ee23977-16b5-4ab3-a20e-d8f74f25d7df', '42', '2025-05-23', '2604.66', 'paid']
# 2025-06-16 20:26:15,937 - INFO - Inserting row into billing: ['d3fa2c2b-2c5c-4a4d-b294-ed014b8515cc', '42', '2025-04-14', '1780.95', 'paid']
# 2025-06-16 20:26:15,937 - INFO - Inserting row into billing: ['e8e11a29-8bc4-4f6a-a6a0-adebe40da1a4', '42', '2025-05-31', '2079.91', 'unpaid']
# 2025-06-16 20:26:15,937 - INFO - Inserting row into billing: ['fc24fcce-3917-4c0b-b53c-c320a7de2279', '43', '2025-03-20', '1858.82', 'paid']
# 2025-06-16 20:26:15,938 - INFO - Inserting row into billing: ['df8ad581-7148-4d27-b81b-a8db18b72f70', '43', '2025-05-29', '1442.43', 'paid']
# 2025-06-16 20:26:15,938 - INFO - Inserting row into billing: ['d27977c3-db2a-416e-b963-221cb6d7530f', '43', '2025-03-20', '707.6', 'unpaid']
# 2025-06-16 20:26:15,939 - INFO - Inserting row into billing: ['9f451869-c17a-49df-b69f-fd7cea1318d5', '44', '2025-06-14', '1102.27', 'paid']
# 2025-06-16 20:26:15,939 - INFO - Inserting row into billing: ['165b00be-61fd-4058-b870-1aaa3222df25', '44', '2025-04-11', '2747.94', 'paid']
# 2025-06-16 20:26:15,940 - INFO - Inserting row into billing: ['6b44dfb7-25f1-4f97-aeee-b0e8f8cbaed2', '44', '2025-05-06', '2039.48', 'unpaid']
# 2025-06-16 20:26:15,940 - INFO - Inserting row into billing: ['42c49309-ff7c-44c5-804a-52a40c2cccea', '45', '2025-05-07', '614.01', 'paid']
# 2025-06-16 20:26:15,941 - INFO - Inserting row into billing: ['0fdf377f-21d8-4e75-92a0-a41bd7c88046', '45', '2025-04-24', '1207.89', 'unpaid']
# 2025-06-16 20:26:15,941 - INFO - Inserting row into billing: ['b7910941-cde6-4a9f-affe-ce6355362e02', '45', '2025-06-06', '2798.35', 'unpaid']
# 2025-06-16 20:26:15,942 - INFO - Inserting row into billing: ['6b3c2bf9-ad11-4add-8454-6036c58e64a8', '46', '2025-03-24', '773.26', 'paid']
# 2025-06-16 20:26:15,942 - INFO - Inserting row into billing: ['9991fb31-5067-462b-9264-4637b7f06490', '46', '2025-04-08', '2962.13', 'paid']
# 2025-06-16 20:26:15,943 - INFO - Inserting row into billing: ['5318e864-25dd-4278-b525-5f8081689f59', '46', '2025-05-27', '1280.06', 'unpaid']
# 2025-06-16 20:26:15,943 - INFO - Inserting row into billing: ['32d21191-6a3b-4284-8aae-d12650dcdc62', '47', '2025-05-23', '2803.62', 'paid']
# 2025-06-16 20:26:15,944 - INFO - Inserting row into billing: ['644fe7af-3ad4-410e-8d0b-ab3863c644f4', '47', '2025-05-10', '1084.52', 'paid']
# 2025-06-16 20:26:15,944 - INFO - Inserting row into billing: ['6a396418-fd24-49e3-a0fe-4426452fa1ae', '47', '2025-04-22', '2800.43', 'paid']
# 2025-06-16 20:26:15,944 - INFO - Inserting row into billing: ['c6e9efb8-c716-40fe-836b-6c7ba38f98db', '48', '2025-04-17', '1485.73', 'paid']
# 2025-06-16 20:26:15,945 - INFO - Inserting row into billing: ['863790b1-4436-4c5c-bf24-0225707419f3', '48', '2025-05-22', '1489.78', 'unpaid']
# 2025-06-16 20:26:15,945 - INFO - Inserting row into billing: ['f766bd9f-53b1-4259-9778-be386d9b22e3', '48', '2025-05-31', '594.25', 'paid']
# 2025-06-16 20:26:15,947 - INFO - Inserting row into billing: ['06d30d0a-bb37-47a0-b11d-d86b0ffe835b', '49', '2025-04-08', '527.64', 'paid']
# 2025-06-16 20:26:15,947 - INFO - Inserting row into billing: ['da6892eb-ccb6-474f-b5e9-72cac4af328e', '49', '2025-04-27', '2908.72', 'paid']
# 2025-06-16 20:26:15,948 - INFO - Inserting row into billing: ['95df8412-f54b-4ecf-b4b8-64668536c6ba', '49', '2025-03-29', '1004.87', 'paid']
# 2025-06-16 20:26:15,948 - INFO - Inserting row into billing: ['75fa059e-f931-4e48-83ae-45cf0509482e', '50', '2025-05-25', '1382.48', 'paid']
# 2025-06-16 20:26:15,949 - INFO - Inserting row into billing: ['b06c7b18-47f2-44c4-8aca-c585c741cab8', '50', '2025-05-14', '2654.75', 'paid']
# 2025-06-16 20:26:15,950 - INFO - Inserting row into billing: ['9e1b02bd-ae38-4435-af2f-3aeb29635e05', '50', '2025-05-20', '1484.53', 'paid']
# 2025-06-16 20:26:15,950 - INFO - Inserting row into billing: ['8143a425-15cd-4766-9459-12f98f452f73', '51', '2025-06-09', '628.09', 'unpaid']
# 2025-06-16 20:26:15,950 - INFO - Inserting row into billing: ['a4c9a318-5eb7-4ead-928c-8231cf82e21f', '51', '2025-06-15', '2032.74', 'paid']
# 2025-06-16 20:26:15,951 - INFO - Inserting row into billing: ['3bcd838c-bbaa-4f97-b671-ba9789a3898c', '51', '2025-04-02', '2084.76', 'unpaid']
# 2025-06-16 20:26:15,951 - INFO - Inserting row into billing: ['bdff3629-4f21-4add-b467-75e3dde1d60e', '52', '2025-05-24', '1396.43', 'paid']
# 2025-06-16 20:26:15,953 - INFO - Inserting row into billing: ['bca75466-00f2-45e4-a89f-da0b0e1968d9', '52', '2025-03-28', '752.92', 'unpaid']
# 2025-06-16 20:26:15,954 - INFO - Inserting row into billing: ['6b9c71e6-215f-4ecc-91a0-8f8b79448caa', '52', '2025-06-10', '2432.94', 'paid']
# 2025-06-16 20:26:15,954 - INFO - Inserting row into billing: ['1fcc60c3-c689-425c-9400-b0ddc0d0db82', '53', '2025-05-28', '1079.95', 'paid']
# 2025-06-16 20:26:15,955 - INFO - Inserting row into billing: ['072a17b9-c0aa-4d2c-a4b4-d263116448ee', '53', '2025-06-04', '1004.52', 'unpaid']
# 2025-06-16 20:26:15,955 - INFO - Inserting row into billing: ['0a8ffe84-cc74-4d00-a6a9-aa276b314927', '53', '2025-05-14', '673.84', 'paid']
# 2025-06-16 20:26:15,956 - INFO - Inserting row into billing: ['8bc9b1a0-9062-4c3c-9eeb-bbb712768b89', '54', '2025-04-13', '2100.49', 'unpaid']
# 2025-06-16 20:26:15,956 - INFO - Inserting row into billing: ['5ed5610d-f099-4c17-a49f-52d6ff6b0f8c', '54', '2025-05-26', '1139.31', 'unpaid']
# 2025-06-16 20:26:15,957 - INFO - Inserting row into billing: ['9a4ad4f5-59ff-4813-923d-fc20244c927b', '54', '2025-03-31', '2121.36', 'paid']
# 2025-06-16 20:26:15,957 - INFO - Inserting row into billing: ['bb83c374-8f63-4634-bd66-5bcab8d85554', '55', '2025-03-26', '599.64', 'unpaid']
# 2025-06-16 20:26:15,958 - INFO - Inserting row into billing: ['e4d593bb-9a08-46c2-a45b-a618313a3947', '55', '2025-06-08', '1362.73', 'unpaid']
# 2025-06-16 20:26:15,958 - INFO - Inserting row into billing: ['9cdedbbd-50ca-41b0-a1a2-984e55515e9a', '55', '2025-06-15', '1288.77', 'unpaid']
# 2025-06-16 20:26:15,959 - INFO - Inserting row into billing: ['8c49c16b-251b-4034-8158-a3f7bc37a830', '56', '2025-05-31', '1852.03', 'unpaid']
# 2025-06-16 20:26:15,959 - INFO - Inserting row into billing: ['87309e04-575d-42f5-bfd6-eafe9abe97cd', '56', '2025-05-28', '687.51', 'unpaid']
# 2025-06-16 20:26:15,960 - INFO - Inserting row into billing: ['b7378070-c567-4178-bbd5-7fceef61d64e', '56', '2025-06-04', '1344.43', 'unpaid']
# 2025-06-16 20:26:15,961 - INFO - Inserting row into billing: ['a3d5f2b9-9443-4396-8119-91a89396c049', '57', '2025-05-14', '2629.41', 'paid']
# 2025-06-16 20:26:15,962 - INFO - Inserting row into billing: ['bb706877-141d-4265-9a24-68cd49510640', '57', '2025-03-17', '1868.58', 'paid']
# 2025-06-16 20:26:15,962 - INFO - Inserting row into billing: ['d5b6c45f-d264-4d1b-b41e-1a0b8f9cfa55', '57', '2025-05-28', '1371.69', 'unpaid']
# 2025-06-16 20:26:15,962 - INFO - Inserting row into billing: ['ed365507-d36f-4c52-874e-abcff6e82e21', '58', '2025-05-17', '2522.36', 'unpaid']
# 2025-06-16 20:26:15,963 - INFO - Inserting row into billing: ['09998bc4-3085-414e-91a1-1f2fdb2bc33d', '58', '2025-06-14', '1826.74', 'unpaid']
# 2025-06-16 20:26:15,964 - INFO - Inserting row into billing: ['94fa33d8-d698-445d-afb0-97797caadefa', '58', '2025-06-02', '2245.05', 'unpaid']
# 2025-06-16 20:26:15,964 - INFO - Inserting row into billing: ['1d3bf7b2-1a14-4ae6-94dc-e6638a222fbf', '59', '2025-04-22', '2910.79', 'paid']
# ...
# 2025-06-16 20:26:18,194 - INFO - Inserting row into consumption_logs: ['59_20250511', '59', '2025-05-11', '10:28:36', '238.22']
# 2025-06-16 20:26:18,195 - INFO - Inserting row into consumption_logs: ['60_20250608', '60', '2025-06-08', '20:26:03', '474.11']
# 2025-06-16 20:26:18,195 - INFO - Inserting row into consumption_logs: ['60_20250422', '60', '2025-04-22', '15:28:44', '134.08']
# 2025-06-16 20:26:18,196 - INFO - Inserting row into consumption_logs: ['60_20250514', '60', '2025-05-14', '23:27:45', '231.34']
# 2025-06-16 20:26:18,196 - INFO - Inserting row into consumption_logs: ['61_20250510', '61', '2025-05-10', '19:05:43', '206.83']
# 2025-06-16 20:26:18,197 - INFO - Inserting row into consumption_logs: ['61_20250316', '61', '2025-03-16', '08:57:34', '272.04']
# 2025-06-16 20:26:18,197 - INFO - Inserting row into consumption_logs: ['61_20250318', '61', '2025-03-18', '19:03:27', '128.41']
# 2025-06-16 20:26:18,198 - INFO - Inserting row into consumption_logs: ['62_20250523', '62', '2025-05-23', '01:21:04', '183.76']
# 2025-06-16 20:26:18,198 - INFO - Inserting row into consumption_logs: ['62_20250612', '62', '2025-06-12', '09:23:26', '267.81']
# 2025-06-16 20:26:18,199 - INFO - Inserting row into consumption_logs: ['62_20250517', '62', '2025-05-17', '22:44:49', '199.72']
# 2025-06-16 20:26:18,199 - INFO - Inserting row into consumption_logs: ['63_20250530', '63', '2025-05-30', '07:45:41', '147.44']
# 2025-06-16 20:26:18,199 - INFO - Inserting row into consumption_logs: ['63_20250420', '63', '2025-04-20', '11:04:48', '105.68']
# 2025-06-16 20:26:18,200 - INFO - Inserting row into consumption_logs: ['63_20250330', '63', '2025-03-30', '05:46:10', '179.34']
# 2025-06-16 20:26:18,200 - INFO - Inserting row into consumption_logs: ['64_20250404', '64', '2025-04-04', '19:36:14', '357.38']
# 2025-06-16 20:26:18,200 - INFO - Inserting row into consumption_logs: ['64_20250601', '64', '2025-06-01', '04:16:41', '344.66']
# 2025-06-16 20:26:18,201 - INFO - Inserting row into consumption_logs: ['64_20250412', '64', '2025-04-12', '08:39:40', '64.84']
# 2025-06-16 20:26:18,201 - INFO - Inserting row into consumption_logs: ['65_20250320', '65', '2025-03-20', '17:11:50', '110.25']
# 2025-06-16 20:26:18,202 - INFO - Inserting row into consumption_logs: ['65_20250527', '65', '2025-05-27', '05:38:09', '411.51']
# 2025-06-16 20:26:18,202 - INFO - Inserting row into consumption_logs: ['65_20250501', '65', '2025-05-01', '07:15:11', '272.96']
# 2025-06-16 20:26:18,203 - INFO - Inserting row into consumption_logs: ['66_20250408', '66', '2025-04-08', '08:53:16', '117.45']
# 2025-06-16 20:26:18,203 - INFO - Inserting row into consumption_logs: ['66_20250521', '66', '2025-05-21', '23:36:13', '189.66']
# 2025-06-16 20:26:18,204 - INFO - Inserting row into consumption_logs: ['66_20250507', '66', '2025-05-07', '11:02:44', '53.57']
# 2025-06-16 20:26:18,204 - INFO - Inserting row into consumption_logs: ['67_20250512', '67', '2025-05-12', '08:57:17', '466.67']
# 2025-06-16 20:26:18,205 - INFO - Inserting row into consumption_logs: ['67_20250324', '67', '2025-03-24', '21:51:52', '146.18']
# 2025-06-16 20:26:18,205 - INFO - Inserting row into consumption_logs: ['67_20250504', '67', '2025-05-04', '10:11:43', '376.77']
# 2025-06-16 20:26:18,206 - INFO - Inserting row into consumption_logs: ['68_20250430', '68', '2025-04-30', '15:02:55', '445.95']
# 2025-06-16 20:26:18,206 - INFO - Inserting row into consumption_logs: ['68_20250511', '68', '2025-05-11', '08:11:56', '322.97']
# 2025-06-16 20:26:18,207 - INFO - Inserting row into consumption_logs: ['68_20250403', '68', '2025-04-03', '03:36:22', '62.27']
# 2025-06-16 20:26:18,207 - INFO - Inserting row into consumption_logs: ['69_20250528', '69', '2025-05-28', '18:19:00', '206.38']
# 2025-06-16 20:26:18,207 - INFO - Inserting row into consumption_logs: ['69_20250328', '69', '2025-03-28', '04:37:34', '465.6']
# 2025-06-16 20:26:18,208 - INFO - Inserting row into consumption_logs: ['69_20250522', '69', '2025-05-22', '19:29:38', '144.12']
# 2025-06-16 20:26:18,208 - INFO - Inserting row into consumption_logs: ['70_20250419', '70', '2025-04-19', '15:01:53', '63.03']
# 2025-06-16 20:26:18,208 - INFO - Inserting row into consumption_logs: ['70_20250521', '70', '2025-05-21', '14:13:05', '331.52']
# 2025-06-16 20:26:18,210 - INFO - Inserting row into consumption_logs: ['70_20250614', '70', '2025-06-14', '17:08:36', '136.57']
# 2025-06-16 20:26:18,210 - INFO - Inserting row into consumption_logs: ['71_20250601', '71', '2025-06-01', '00:26:25', '310.39']
# 2025-06-16 20:26:18,211 - INFO - Inserting row into consumption_logs: ['71_20250324', '71', '2025-03-24', '08:21:37', '382.52']
# 2025-06-16 20:26:18,211 - INFO - Inserting row into consumption_logs: ['71_20250420', '71', '2025-04-20', '22:06:57', '303.43']
# 2025-06-16 20:26:18,212 - INFO - Inserting row into consumption_logs: ['72_20250514', '72', '2025-05-14', '00:11:27', '468.04']
# 2025-06-16 20:26:18,212 - INFO - Inserting row into consumption_logs: ['72_20250428', '72', '2025-04-28', '10:53:48', '314.83']
# 2025-06-16 20:26:18,212 - INFO - Inserting row into consumption_logs: ['72_20250407', '72', '2025-04-07', '16:36:28', '118.2']
# 2025-06-16 20:26:18,213 - INFO - Inserting row into consumption_logs: ['73_20250527', '73', '2025-05-27', '20:27:42', '458.93']
# 2025-06-16 20:26:18,213 - INFO - Inserting row into consumption_logs: ['73_20250411', '73', '2025-04-11', '05:09:04', '309.15']
# 2025-06-16 20:26:18,214 - INFO - Inserting row into consumption_logs: ['73_20250324', '73', '2025-03-24', '01:39:48', '134.16']
# 2025-06-16 20:26:18,214 - INFO - Inserting row into consumption_logs: ['74_20250607', '74', '2025-06-07', '04:37:14', '217.53']
# 2025-06-16 20:26:18,215 - INFO - Inserting row into consumption_logs: ['74_20250405', '74', '2025-04-05', '17:08:57', '416.11']
# 2025-06-16 20:26:18,215 - INFO - Inserting row into consumption_logs: ['74_20250503', '74', '2025-05-03', '20:29:11', '384.08']
# 2025-06-16 20:26:18,216 - INFO - Inserting row into consumption_logs: ['75_20250428', '75', '2025-04-28', '04:29:47', '461.68']
# 2025-06-16 20:26:18,216 - INFO - Inserting row into consumption_logs: ['75_20250531', '75', '2025-05-31', '13:27:03', '361.34']
# 2025-06-16 20:26:18,217 - INFO - Inserting row into consumption_logs: ['75_20250317', '75', '2025-03-17', '14:07:03', '365.68']
# 2025-06-16 20:26:18,217 - INFO - Inserting row into consumption_logs: ['76_20250421', '76', '2025-04-21', '10:18:36', '87.6']
# 2025-06-16 20:26:18,217 - INFO - Inserting row into consumption_logs: ['76_20250421', '76', '2025-04-21', '22:44:29', '456.84']
# 2025-06-16 20:26:18,218 - INFO - Inserting row into consumption_logs: ['76_20250529', '76', '2025-05-29', '14:14:53', '120.16']
# 2025-06-16 20:26:18,219 - INFO - Inserting row into consumption_logs: ['77_20250603', '77', '2025-06-03', '06:26:46', '146.51']
# 2025-06-16 20:26:18,219 - INFO - Inserting row into consumption_logs: ['77_20250501', '77', '2025-05-01', '05:51:14', '85.24']
# 2025-06-16 20:26:18,220 - INFO - Inserting row into consumption_logs: ['77_20250322', '77', '2025-03-22', '00:02:13', '281.21']
# 2025-06-16 20:26:18,220 - INFO - Inserting row into consumption_logs: ['78_20250527', '78', '2025-05-27', '10:56:38', '237.1']
# 2025-06-16 20:26:18,220 - INFO - Inserting row into consumption_logs: ['78_20250505', '78', '2025-05-05', '21:07:59', '166.44']
# 2025-06-16 20:26:18,220 - INFO - Inserting row into consumption_logs: ['78_20250430', '78', '2025-04-30', '10:31:46', '447.61']
# 2025-06-16 20:26:18,221 - INFO - Inserting row into consumption_logs: ['79_20250320', '79', '2025-03-20', '14:30:00', '126.04']
# 2025-06-16 20:26:18,221 - INFO - Inserting row into consumption_logs: ['79_20250430', '79', '2025-04-30', '21:09:16', '129.15']
# 2025-06-16 20:26:18,222 - INFO - Inserting row into consumption_logs: ['79_20250421', '79', '2025-04-21', '17:34:28', '494.23']
# 2025-06-16 20:26:18,222 - INFO - Inserting row into consumption_logs: ['80_20250523', '80', '2025-05-23', '21:59:22', '413.86']
# 2025-06-16 20:26:18,223 - INFO - Inserting row into consumption_logs: ['80_20250429', '80', '2025-04-29', '22:22:03', '483.03']
# 2025-06-16 20:26:18,223 - INFO - Inserting row into consumption_logs: ['80_20250506', '80', '2025-05-06', '05:55:55', '165.62']
# 2025-06-16 20:26:18,224 - INFO - Inserting row into consumption_logs: ['81_20250518', '81', '2025-05-18', '12:09:48', '100.22']
# 2025-06-16 20:26:18,225 - INFO - Inserting row into consumption_logs: ['81_20250529', '81', '2025-05-29', '17:14:11', '107.9']
# 2025-06-16 20:26:18,226 - INFO - Inserting row into consumption_logs: ['81_20250513', '81', '2025-05-13', '09:06:53', '113.88']
# 2025-06-16 20:26:18,226 - INFO - Inserting row into consumption_logs: ['82_20250327', '82', '2025-03-27', '15:35:29', '386.14']
# 2025-06-16 20:26:18,227 - INFO - Inserting row into consumption_logs: ['82_20250509', '82', '2025-05-09', '01:45:42', '279.55']
# 2025-06-16 20:26:18,227 - INFO - Inserting row into consumption_logs: ['82_20250411', '82', '2025-04-11', '17:24:11', '373.72']
# 2025-06-16 20:26:18,227 - INFO - Inserting row into consumption_logs: ['83_20250513', '83', '2025-05-13', '02:17:00', '50.6']
# 2025-06-16 20:26:18,228 - INFO - Inserting row into consumption_logs: ['83_20250405', '83', '2025-04-05', '17:09:06', '402.29']
# 2025-06-16 20:26:18,228 - INFO - Inserting row into consumption_logs: ['83_20250319', '83', '2025-03-19', '01:29:24', '254.18']
# 2025-06-16 20:26:18,228 - INFO - Inserting row into consumption_logs: ['84_20250504', '84', '2025-05-04', '12:44:15', '349.46']
# 2025-06-16 20:26:18,230 - INFO - Inserting row into consumption_logs: ['84_20250421', '84', '2025-04-21', '01:51:17', '206.3']
# 2025-06-16 20:26:18,230 - INFO - Inserting row into consumption_logs: ['84_20250520', '84', '2025-05-20', '22:04:05', '220.16']
# 2025-06-16 20:26:18,231 - INFO - Inserting row into consumption_logs: ['85_20250316', '85', '2025-03-16', '08:56:24', '65.35']
# 2025-06-16 20:26:18,231 - INFO - Inserting row into consumption_logs: ['85_20250528', '85', '2025-05-28', '06:52:50', '310.63']
# 2025-06-16 20:26:18,232 - INFO - Inserting row into consumption_logs: ['85_20250507', '85', '2025-05-07', '05:15:44', '288.4']
# 2025-06-16 20:26:18,232 - INFO - Inserting row into consumption_logs: ['86_20250328', '86', '2025-03-28', '22:30:13', '266.65']
# 2025-06-16 20:26:18,233 - INFO - Inserting row into consumption_logs: ['86_20250518', '86', '2025-05-18', '08:30:08', '92.19']
# 2025-06-16 20:26:18,233 - INFO - Inserting row into consumption_logs: ['86_20250613', '86', '2025-06-13', '20:07:03', '106.53']
# 2025-06-16 20:26:18,234 - INFO - Inserting row into consumption_logs: ['87_20250529', '87', '2025-05-29', '02:43:51', '134.26']
# 2025-06-16 20:26:18,234 - INFO - Inserting row into consumption_logs: ['87_20250527', '87', '2025-05-27', '21:55:11', '202.06']
# 2025-06-16 20:26:18,235 - INFO - Inserting row into consumption_logs: ['87_20250528', '87', '2025-05-28', '20:51:47', '432.6']
# 2025-06-16 20:26:18,235 - INFO - Inserting row into consumption_logs: ['88_20250610', '88', '2025-06-10', '20:07:01', '211.25']
# 2025-06-16 20:26:18,236 - INFO - Inserting row into consumption_logs: ['88_20250327', '88', '2025-03-27', '08:27:48', '69.82']
# 2025-06-16 20:26:18,237 - INFO - Inserting row into consumption_logs: ['88_20250322', '88', '2025-03-22', '08:24:33', '470.38']
# 2025-06-16 20:26:18,237 - INFO - Inserting row into consumption_logs: ['89_20250609', '89', '2025-06-09', '12:24:05', '223.14']
# 2025-06-16 20:26:18,238 - INFO - Inserting row into consumption_logs: ['89_20250321', '89', '2025-03-21', '02:16:23', '57.1']
# 2025-06-16 20:26:18,238 - INFO - Inserting row into consumption_logs: ['89_20250417', '89', '2025-04-17', '18:35:26', '412.0']
# 2025-06-16 20:26:18,239 - INFO - Inserting row into consumption_logs: ['90_20250419', '90', '2025-04-19', '12:12:51', '457.46']
# 2025-06-16 20:26:18,239 - INFO - Inserting row into consumption_logs: ['90_20250507', '90', '2025-05-07', '15:10:52', '79.31']
# 2025-06-16 20:26:18,240 - INFO - Inserting row into consumption_logs: ['90_20250531', '90', '2025-05-31', '12:03:51', '252.22']
# 2025-06-16 20:26:18,240 - INFO - Inserting row into consumption_logs: ['91_20250420', '91', '2025-04-20', '11:19:21', '335.43']
# 2025-06-16 20:26:18,240 - INFO - Inserting row into consumption_logs: ['91_20250417', '91', '2025-04-17', '05:25:30', '339.13']
# 2025-06-16 20:26:18,240 - INFO - Inserting row into consumption_logs: ['91_20250404', '91', '2025-04-04', '05:41:31', '288.84']
# 2025-06-16 20:26:18,242 - INFO - Inserting row into consumption_logs: ['92_20250603', '92', '2025-06-03', '00:39:08', '321.01']
# 2025-06-16 20:26:18,243 - INFO - Inserting row into consumption_logs: ['92_20250328', '92', '2025-03-28', '19:27:11', '127.51']
# 2025-06-16 20:26:18,243 - INFO - Inserting row into consumption_logs: ['92_20250423', '92', '2025-04-23', '23:36:22', '467.95']
# 2025-06-16 20:26:18,244 - INFO - Inserting row into consumption_logs: ['93_20250318', '93', '2025-03-18', '11:17:47', '251.15']
# 2025-06-16 20:26:18,245 - INFO - Inserting row into consumption_logs: ['93_20250509', '93', '2025-05-09', '18:13:45', '162.38']
# 2025-06-16 20:26:18,245 - INFO - Inserting row into consumption_logs: ['93_20250318', '93', '2025-03-18', '11:51:03', '159.24']
# 2025-06-16 20:26:18,246 - INFO - Inserting row into consumption_logs: ['94_20250413', '94', '2025-04-13', '04:17:15', '448.81']
# 2025-06-16 20:26:18,246 - INFO - Inserting row into consumption_logs: ['94_20250401', '94', '2025-04-01', '19:10:05', '300.98']
# 2025-06-16 20:26:18,247 - INFO - Inserting row into consumption_logs: ['94_20250514', '94', '2025-05-14', '22:11:50', '100.19']
# 2025-06-16 20:26:18,247 - INFO - Inserting row into consumption_logs: ['95_20250603', '95', '2025-06-03', '00:38:04', '304.44']
# 2025-06-16 20:26:18,248 - INFO - Inserting row into consumption_logs: ['95_20250518', '95', '2025-05-18', '16:44:15', '264.23']
# 2025-06-16 20:26:18,248 - INFO - Inserting row into consumption_logs: ['95_20250425', '95', '2025-04-25', '16:18:02', '360.4']
# 2025-06-16 20:26:18,248 - INFO - Inserting row into consumption_logs: ['96_20250325', '96', '2025-03-25', '12:09:46', '295.85']
# 2025-06-16 20:26:18,249 - INFO - Inserting row into consumption_logs: ['96_20250328', '96', '2025-03-28', '07:11:25', '250.89']
# 2025-06-16 20:26:18,249 - INFO - Inserting row into consumption_logs: ['96_20250513', '96', '2025-05-13', '16:52:35', '96.32']
# 2025-06-16 20:26:18,250 - INFO - Inserting row into consumption_logs: ['97_20250510', '97', '2025-05-10', '22:28:16', '429.62']
# 2025-06-16 20:26:18,250 - INFO - Inserting row into consumption_logs: ['97_20250409', '97', '2025-04-09', '09:48:22', '359.59']
# 2025-06-16 20:26:18,250 - INFO - Inserting row into consumption_logs: ['97_20250411', '97', '2025-04-11', '20:28:57', '188.31']
# 2025-06-16 20:26:18,251 - INFO - Inserting row into consumption_logs: ['98_20250317', '98', '2025-03-17', '18:22:57', '54.25']
# 2025-06-16 20:26:18,251 - INFO - Inserting row into consumption_logs: ['98_20250522', '98', '2025-05-22', '10:18:29', '115.44']
# 2025-06-16 20:26:18,252 - INFO - Inserting row into consumption_logs: ['98_20250529', '98', '2025-05-29', '18:14:24', '206.19']
# 2025-06-16 20:26:18,252 - INFO - Inserting row into consumption_logs: ['99_20250612', '99', '2025-06-12', '13:03:21', '343.35']
# 2025-06-16 20:26:18,253 - INFO - Inserting row into consumption_logs: ['99_20250429', '99', '2025-04-29', '10:24:43', '213.99']
# 2025-06-16 20:26:18,253 - INFO - Inserting row into consumption_logs: ['99_20250614', '99', '2025-06-14', '21:03:20', '222.32']
# 2025-06-16 20:26:18,254 - INFO - Inserting row into consumption_logs: ['100_20250525', '100', '2025-05-25', '05:08:20', '375.83']
# 2025-06-16 20:26:18,254 - INFO - Inserting row into consumption_logs: ['100_20250322', '100', '2025-03-22', '02:30:27', '450.84']
# 2025-06-16 20:26:18,254 - INFO - Inserting row into consumption_logs: ['100_20250323', '100', '2025-03-23', '00:58:35', '430.47']
# Consumption logs table created and data inserted successfully.
